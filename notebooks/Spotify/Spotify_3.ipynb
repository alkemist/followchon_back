# %%
import numpy as np
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials, SpotifyOAuth
import sys

# %%
sp = spotipy.Spotify(
    client_credentials_manager = SpotifyClientCredentials(
        client_id='009120d1cc7040ebbb89b1828e4c76cc',
        client_secret='9fc76097d0d44c34bb62accbe98be197',
    ),
    #auth_manager=SpotifyOAuth(scope='user-library-read')
)

sp.me()
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/me/ with Params: {} returned 401 due to Valid user authentication required
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/Projects/followchon_back/venv/lib/python3.11/site-packages/spotipy/client.py:275, in Spotify._internal_call(self, method, url, payload, params)
#     270 response = self._session.request(
#     271     method, url, headers=headers, proxies=self.proxies,
#     272     timeout=self.requests_timeout, **args
#     273 )
# --> 275 response.raise_for_status()
#     276 results = response.json()
#
# File ~/Projects/followchon_back/venv/lib/python3.11/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/me/
#
# ...

# %%
df = pd.read_csv('Spotify/data/Streaming_tracks.csv')
df
# Out:
#                           uid               artist artist_genre  \
# 0      1SYOjkkPEgoUFcqvAFzUkC           Noir Désir          NaN
# 1      1rONEDBEkebH436T1uSVTe           Noir Désir          NaN
# 2      6P7wGICOuPLL8WKomBlqyR                Duffy          NaN
# 3      76bIWqpWvdgRt19nTpoCVW            The Kinks          NaN
# 4      6SGpMifJv6k5M1ciOaeBR6          The Turtles          NaN
# ...                       ...                  ...          ...
# 55246  6KatXb78ydvl8WzFxjwO7P          Hospitality          NaN
# 55247  3N4EQNTo6j3GU7s9mRufBD              The Dig          NaN
# 55248  4MSgoaK6rkoNWb28GS3AUL       Future Islands          NaN
# 55249  6KJN2Fq7r6uU0ksmObogUg         French Kicks          NaN
# 55250  6i1VewefsH1p9K68myrJoF  Blackbird Blackbird          NaN
#
#                                              album  album_year  \
# 0                             Noir Desir En Public         NaN
# 1                             Noir Desir En Public         NaN
# ...

# %%
results = sp.search(q='weezer', limit=20)

# %%
for idx, item in enumerate(results['tracks']['items']):
    print(item.keys())
    print(idx, item['artists'][0]['name'], " – ", item['name'])
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'is_playable', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])
# 0 Weezer  –  Island In The Sun
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'is_playable', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])
# 1 Weezer  –  Buddy Holly
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'is_playable', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])
# 2 Weezer  –  Undone - The Sweater Song
# ...

# %%
for id in df['uid'].values:
    print(id)
    features = sp.audio_features([f'spotify:track:{id}'])
    print(features)

    break
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/audio-features/?ids=1SYOjkkPEgoUFcqvAFzUkC with Params: {} returned 403 due to None
# 1SYOjkkPEgoUFcqvAFzUkC
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/Projects/followchon_back/venv/lib/python3.11/site-packages/spotipy/client.py:275, in Spotify._internal_call(self, method, url, payload, params)
#     270 response = self._session.request(
#     271     method, url, headers=headers, proxies=self.proxies,
#     272     timeout=self.requests_timeout, **args
#     273 )
# --> 275 response.raise_for_status()
#     276 results = response.json()
#
# File ~/Projects/followchon_back/venv/lib/python3.11/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# ...
